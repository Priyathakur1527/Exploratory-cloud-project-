# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("wrangling_dataset_100.csv")

# %%
df
# Out:
#    Customer_ID  Total_Purchase_Amount  Frequency_of_Purchase  Customer_Tenure  \
# 0        CUST1                    510                      2                2
# 1        CUST2                    520                      3                3
# 2        CUST3                    530                      4                4
# 3        CUST4                    540                      5                5
# 4        CUST5                    550                      6                6
# ..         ...                    ...                    ...              ...
# 95      CUST96                   1460                      7                1
# 96      CUST97                   1470                      8                2
# 97      CUST98                   1480                      9                3
# 98      CUST99                   1490                     10                4
# 99     CUST100                   1500                      1                5
#
# ...

# %%
df.head()
# Out:
#   Customer_ID  Total_Purchase_Amount  Frequency_of_Purchase  Customer_Tenure  \
# 0       CUST1                    510                      2                2
# 1       CUST2                    520                      3                3
# 2       CUST3                    530                      4                4
# 3       CUST4                    540                      5                5
# 4       CUST5                    550                      6                6
#
#    Support_Interactions  Email_Open_Rate
# 0                     1             20.1
# 1                     2             20.2
# 2                     0             20.3
# 3                     1             20.4
# 4                     2             20.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            100 non-null    object
#  1   Total_Purchase_Amount  100 non-null    int64
#  2   Frequency_of_Purchase  100 non-null    int64
#  3   Customer_Tenure        100 non-null    int64
#  4   Support_Interactions   100 non-null    int64
#  5   Email_Open_Rate        100 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#        Total_Purchase_Amount  Frequency_of_Purchase  Customer_Tenure  \
# count              100.00000             100.000000       100.000000
# mean              1005.00000               5.500000         6.380000
# std                290.11492               2.886751         3.457622
# min                510.00000               1.000000         1.000000
# 25%                757.50000               3.000000         3.000000
# 50%               1005.00000               5.500000         6.000000
# 75%               1252.50000               8.000000         9.000000
# max               1500.00000              10.000000        12.000000
#
#        Support_Interactions  Email_Open_Rate
# count            100.000000       100.000000
# mean               1.000000        25.050000
# std                0.816497         2.901149
# min                0.000000        20.100000
# 25%                0.000000        22.575000
# 50%                1.000000        25.050000
# ...

# %% [markdown]
# handling the missing values:

# %%
print(df.isnull().sum())
# Out:
# Customer_ID              0
# Total_Purchase_Amount    0
# Frequency_of_Purchase    0
# Customer_Tenure          0
# Support_Interactions     0
# Email_Open_Rate          0
# dtype: int64

# %% [markdown]
# Remove the duplicate values:

# %%
df = df.drop_duplicates()

# %% [markdown]
# Normalize and standardize data

# %%
# Normalize Total_Purchase_Amount and Frequency_of_Purchase
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[["Total_Purchase_Amount", "Frequency_of_Purchase"]] = scaler.fit_transform(
    df[["Total_Purchase_Amount", "Frequency_of_Purchase"]]
)

# View normalized data
df.head()
# Out:
#   Customer_ID  Total_Purchase_Amount  Frequency_of_Purchase  Customer_Tenure  \
# 0       CUST1               0.000000               0.111111                2
# 1       CUST2               0.010101               0.222222                3
# 2       CUST3               0.020202               0.333333                4
# 3       CUST4               0.030303               0.444444                5
# 4       CUST5               0.040404               0.555556                6
#
#    Support_Interactions  Email_Open_Rate
# 0                     1             20.1
# 1                     2             20.2
# 2                     0             20.3
# 3                     1             20.4
# 4                     2             20.5

# %%
# Create a new feature for Customer Value: Total_Purchase_Amount * Frequency_of_Purchase
df["Customer_Value"] = df["Total_Purchase_Amount"] * df["Frequency_of_Purchase"]

# Calculate customer tenure in years
df["Customer_Tenure_Years"] = df["Customer_Tenure"] / 12

# View new features
df[["Customer_Value", "Customer_Tenure_Years"]].head()
# Out:
#    Customer_Value  Customer_Tenure_Years
# 0        0.000000               0.166667
# 1        0.002245               0.250000
# 2        0.006734               0.333333
# 3        0.013468               0.416667
# 4        0.022447               0.500000

# %%
# Validate the final dataset
print("Final Dataset Info:")
df.info()

# Save the cleaned dataset
df.to_csv("cleaned_wrangling_dataset.csv", index=False)
print("Cleaned dataset saved successfully!")
# Out:
# Final Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            100 non-null    object
#  1   Total_Purchase_Amount  100 non-null    float64
#  2   Frequency_of_Purchase  100 non-null    float64
#  3   Customer_Tenure        100 non-null    int64
#  4   Support_Interactions   100 non-null    int64
#  5   Email_Open_Rate        100 non-null    float64
#  6   Customer_Value         100 non-null    float64
#  7   Customer_Tenure_Years  100 non-null    float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 6.4+ KB
# Cleaned dataset saved successfully!
