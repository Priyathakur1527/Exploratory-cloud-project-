# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Exploratory Titanic datset

# %%
df = pd.read_csv("Titanic_Dataset_100.csv")

# %%
df
# Out:
#     PassengerID  Survived  Pclass  \
# 0             1         0       3
# 1             2         0       1
# 2             3         1       3
# 3             4         0       1
# 4             5         0       1
# ..          ...       ...     ...
# 95           96         1       1
# 96           97         1       2
# 97           98         1       1
# 98           99         0       1
# 99          100         0       2
#
#                                                  Name     Sex  Age  SibSp  \
# 0                      Palsson, Master. Gosta Leonard    male    2      2
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    male    7      1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...    male   31      1
# 3                            Allen, Mr. William Henry    male   50      4
# 4   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   77      0
# ..                                                ...     ...  ...    ...
# 95                            McCarthy, Mr. Timothy J    male   66      1
# 96  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   77      2
# 97  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    9      4
# 98                     Palsson, Master. Gosta Leonard  female    3      1
# 99                            McCarthy, Mr. Timothy J    male   46      5
#
#     Parch            Ticket    Fare Embarked
# 0       5            349909   18.48        S
# 1       1            349909  464.49        C
# 2       3             17463  285.49        C
# 3       0            349909   27.00        S
# 4       2            373450   26.99        C
# ..    ...               ...     ...      ...
# 95      0            349909   29.37        Q
# 96      4            330877  196.89        C
# 97      5             17463   62.33        S
# 98      1            113803   87.66        Q
# 99      0  STON/O2. 3101282  205.01        C
#
# [100 rows x 11 columns]

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of     PassengerID  Survived  Pclass  \
# 0             1         0       3
# 1             2         0       1
# 2             3         1       3
# 3             4         0       1
# 4             5         0       1
# ..          ...       ...     ...
# 95           96         1       1
# 96           97         1       2
# 97           98         1       1
# 98           99         0       1
# 99          100         0       2
#
#                                                  Name     Sex  Age  SibSp  \
# 0                      Palsson, Master. Gosta Leonard    male    2      2
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    male    7      1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...    male   31      1
# 3                            Allen, Mr. William Henry    male   50      4
# 4   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   77      0
# ..                                                ...     ...  ...    ...
# 95                            McCarthy, Mr. Timothy J    male   66      1
# 96  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   77      2
# 97  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    9      4
# 98                     Palsson, Master. Gosta Leonard  female    3      1
# 99                            McCarthy, Mr. Timothy J    male   46      5
#
#     Parch            Ticket    Fare Embarked
# 0       5            349909   18.48        S
# 1       1            349909  464.49        C
# 2       3             17463  285.49        C
# 3       0            349909   27.00        S
# 4       2            373450   26.99        C
# ..    ...               ...     ...      ...
# 95      0            349909   29.37        Q
# 96      4            330877  196.89        C
# 97      5             17463   62.33        S
# 98      1            113803   87.66        Q
# 99      0  STON/O2. 3101282  205.01        C
#
# [100 rows x 11 columns]>

# %% [markdown]
# Overview of the Titanic Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerID  100 non-null    int64
#  1   Survived     100 non-null    int64
#  2   Pclass       100 non-null    int64
#  3   Name         100 non-null    object
#  4   Sex          100 non-null    object
#  5   Age          100 non-null    int64
#  6   SibSp        100 non-null    int64
#  7   Parch        100 non-null    int64
#  8   Ticket       100 non-null    object
#  9   Fare         100 non-null    float64
#  10  Embarked     100 non-null    object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 8.7+ KB

# %% [markdown]
# Checking for the null value

# %%
print(df.isnull().sum())
# Out:
# PassengerID    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Basic stastics for numerical column

# %%
df.describe()
# Out:
#        PassengerID    Survived      Pclass         Age       SibSp  \
# count   100.000000  100.000000  100.000000  100.000000  100.000000
# mean     50.500000    0.510000    2.060000   36.620000    2.190000
# std      29.011492    0.502418    0.814267   24.544242    1.593516
# min       1.000000    0.000000    1.000000    1.000000    0.000000
# 25%      25.750000    0.000000    1.000000   13.750000    1.000000
# 50%      50.500000    1.000000    2.000000   36.000000    2.000000
# 75%      75.250000    1.000000    3.000000   60.000000    4.000000
# max     100.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  100.000000  100.000000
# mean     2.310000  234.443500
# std      1.618673  135.218964
# min      0.000000    8.610000
# 25%      1.000000  131.835000
# 50%      2.000000  227.090000
# 75%      4.000000  347.880000
# max      5.000000  492.060000

# %% [markdown]
# No missing values:

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Age']
# Out:
# 0      2
# 1      7
# 2     31
# 3     50
# 4     77
#       ..
# 95    66
# 96    77
# 97     9
# 98     3
# 99    46
# Name: Age, Length: 100, dtype: int64

# %% [markdown]
# Data Visualization: Survival rate by gender

# %%
sns.countplot(x='Survived', hue='Sex', data=df)
plt.title("Survival Rates by Gender")
plt.show()

sns.countplot(x='Survived', hue='Pclass', data=df)
plt.title("Survival Rates by Passenger Class")
plt.show()

# %% [markdown]
# Distribution of age:

# %%
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# Corelation matrix

# %%
numerical_df = df.select_dtypes(include=np.number)

# %%
correlation_matrix = numerical_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
