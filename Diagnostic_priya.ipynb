# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diagnostic_dataset 100.csv")

# %%
df
# Out:
#           Date  Sales_Amount  Inventory_Level  Customer_Feedback  \
# 0   2024-06-01           990              199                  4
# 1   2024-06-02           980              198                  3
# 2   2024-06-03           970              197                  2
# 3   2024-06-04           960              196                  1
# 4   2024-06-05           950              195                  5
# ..         ...           ...              ...                ...
# 95  2024-09-04           940              184                  4
# 96  2024-09-05           930              183                  3
# 97  2024-09-06           920              182                  2
# 98  2024-09-07           910              181                  1
# 99  2024-09-08          1000              200                  5
#
#     Competitor_Pricing Market_Trend
# 0                 90.5   Increasing
# 1                 91.0   Decreasing
# 2                 91.5       Stable
# 3                 92.0   Increasing
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                100 non-null    object
#  1   Sales_Amount        100 non-null    int64
#  2   Inventory_Level     100 non-null    int64
#  3   Customer_Feedback   100 non-null    int64
#  4   Competitor_Pricing  100 non-null    float64
#  5   Market_Trend        100 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# Drop Duplicate data

# %%
df = df.drop_duplicates()

# %% [markdown]
# Sales trends iver time with the visualiation:

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Plot sales trends over time
plt.figure(figsize=(10, 6))
plt.plot(df["Date"], df["Sales_Amount"], label="Sales Amount", color="blue")
plt.xticks(rotation=45)
plt.title("Sales Trends Over Time")
plt.xlabel("Date")
plt.ylabel("Sales Amount")
plt.legend()
plt.show()

# %% [markdown]
# Correlation analysis

# %%
# Calculate correlations
correlation_matrix = df[["Sales_Amount", "Inventory_Level", "Customer_Feedback", "Competitor_Pricing"]].corr()

# Display the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Countplot of customer feedback scores
plt.figure(figsize=(8, 6))
sns.countplot(x="Customer_Feedback", data=df, palette="viridis")
plt.title("Distribution of Customer Feedback")
plt.xlabel("Feedback Score")
plt.ylabel("Market_Trend")
plt.show()
# Out:
# <ipython-input-28-be8a0895d6b7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Customer_Feedback", data=df, palette="viridis")

# %%
# Group data by Market Trend and calculate average sales
market_trends_analysis = df.groupby("Market_Trend")["Sales_Amount"].mean()

# Bar plot for market trends
plt.figure(figsize=(8, 6))
market_trends_analysis.plot(kind="bar", color=["green", "orange", "blue"])
plt.title("Average Sales by Market Trend")
plt.xlabel("Market Trend")
plt.ylabel("Average Sales Amount")
plt.show()
